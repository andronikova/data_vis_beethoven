# %% [markdown]
# # Mark most essential masterpieces

# %%
import pandas as pd

# %%
df = pd.read_csv('df_fv.csv')

# %%
df
# Out:
#              Op.       WoO   Hess       Biamonti  \
# 0    Op. 1 No. 1       NaN    NaN  Biamonti 62/1
# 1    Op. 1 No. 2       NaN    NaN  Biamonti 62/2
# 2    Op. 1 No. 3       NaN    NaN  Biamonti 62/3
# 3    Op. 2 No. 1       NaN    NaN  Biamonti 87/1
# 4    Op. 2 No. 2       NaN    NaN  Biamonti 87/2
# ..           ...       ...    ...            ...
# 677          NaN       225  303.0            NaN
# 678          NaN       226  260.0            NaN
# 679          NaN       227  277.0            NaN
# 680          NaN  228 No.1    NaN            NaN
# 681          NaN  228 No.2  285.0            NaN
#
#                                        title           key    scoring  \
# 0                   Piano Trios : Piano Trio  E flat major   vn vc pf
# 1                   Piano Trios : Piano Trio       G major   vn vc pf
# 2                   Piano Trios : Piano Trio       C minor   vn vc pf
# 3          Piano Sonatas : Piano Sonata No.1       F minor         pf
# ...

# %%
df['essential']='other'

# %%
essential = 'Most popular compositions'

# %%
df.loc[df['Op.']=='Op. 92',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 68',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 47',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 84',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 23',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 60',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 132',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 133',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 28',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 124',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 115',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 30 No. 2',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 67',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 74',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 93',['essential']]=essential

# %%
df.loc[df['WoO']=='WoO 55',['essential']]=essential

# %%
df.loc[df['WoO']=='WoO 59',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 24',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 53',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 62',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 73',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 67',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 27 No. 2',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 97',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 47',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 55',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 13',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 38',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 18 No. 6',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 31 No. 3',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 125',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 30 No. 3',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 71',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 68',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 92',['essential']]=essential

# %%
df.loc[df['Op.']=='Op. 57',['essential']]=essential

# %%
df[df['title'].str.contains('Symphony')]
# Out:
#          Op.  WoO   Hess      Biamonti  \
# 37    Op. 21  NaN    NaN  Biamonti 203
# 57    Op. 36  NaN    NaN  Biamonti 326
# 58    Op. 36  NaN    NaN  Biamonti 425
# 90    Op. 55  NaN    NaN  Biamonti 406
# 97    Op. 60  NaN    NaN  Biamonti 429
# 105   Op. 67  NaN    NaN  Biamonti 443
# 106   Op. 68  NaN    NaN  Biamonti 453
# 146   Op. 91  NaN    NaN  Biamonti 560
# 147   Op. 92  NaN    NaN  Biamonti 544
# 148   Op. 93  NaN    NaN  Biamonti 659
# 226  Op. 125  NaN    NaN  Biamonti 787
# 517      NaN  NaN    NaN  Biamonti 838
# 542      NaN  NaN    NaN           547
# 594      NaN  NaN     96           NaN
# 638      NaN  NaN  298.0           NaN
#
#                                                  title           key  \
# 37                                       Symphony No.1       C major
# 57                                       Symphony No.2       D major
# 58                                       Symphony No.2       D major
# ...

# %%
df['essential'].value_counts()
# Out:
# other                        650
# Most popular compositions     32
# Name: essential, dtype: int64

# %% [markdown]
# # Voyager

# %%
df.loc[df['Op.']=='Op. 67',['essential']]="Included in Voyager Golden Record"

# %%
df[df['title'].str.contains('13')]
# Out:
#               Op.     WoO Hess        Biamonti  \
# 43   Op. 27 No. 1     NaN  NaN  Biamonti 297/1
# 231       Op. 130     NaN  NaN    Biamonti 830
# 329           NaN  WoO 66  NaN     Biamonti 37
#
#                                                  title           key  \
# 43    Piano Sonatas : Piano Sonata No.13 ('Quasi un...  E flat major
# 231                               String Quartet No.13  B flat major
# 329   Variations on 'Es war einmal ein alter Mann'(13)       A major
#
#         scoring     genre                          name    year  minor  \
# 43           pf  Keyboard  Op. 27 No. 1, Biamonti 297/1  1801.0    0.0
# 231   2vn va vc   Chamber         Op. 130, Biamonti 830  1825.0    0.0
# 329          pf  Keyboard           WoO 66, Biamonti 37  1792.0    0.0
#
#     key_note  Unv. major-minor              type essential
# 43    E flat   NaN       major  Sonata for Piano     other
# 231   B flat   NaN       major    String Quartet     other
# ...

# %%
df.loc[df['Op.']=='Op. 130',['essential']]="Included in Voyager Golden Record"

# %% [markdown]
# # SAVE

# %%
df.to_csv('df_fv.csv',index=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 682 entries, 0 to 681
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Op.          240 non-null    object
#  1   WoO          292 non-null    object
#  2   Hess         226 non-null    object
#  3   Biamonti     546 non-null    object
#  4   title        682 non-null    object
#  5   key          682 non-null    object
#  6   scoring      515 non-null    object
#  7   genre        625 non-null    object
#  8   name         682 non-null    object
#  9   year         640 non-null    float64
#  10  minor        480 non-null    float64
#  11  key_note     682 non-null    object
#  12  Unv.         19 non-null     float64
#  13  major-minor  682 non-null    object
#  14  type         625 non-null    object
#  15  essential    682 non-null    object
# dtypes: float64(3), object(13)
# memory usage: 85.4+ KB
