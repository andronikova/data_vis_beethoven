# %% [markdown]
# # Merge

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ## df_fv_part_1

# %%
df_1 = pd.read_csv('df_fv_part_1.csv')

# %%
df_1.rename(columns={'Title': 'title', 'Key': 'key','Scoring':'scoring', 'Genre':'genre'}, inplace=True)

# %%
df_1.drop(columns=['Comments'], inplace=True)

# %%
df_1['Unv.'] = np.nan

# %%
df_1.head(20)
# Out:
#              Op.  WoO Hess        Biamonti  \
# 0    Op. 1 No. 1  NaN  NaN   Biamonti 62/1
# 1    Op. 1 No. 2  NaN  NaN   Biamonti 62/2
# 2    Op. 1 No. 3  NaN  NaN   Biamonti 62/3
# 3    Op. 2 No. 1  NaN  NaN   Biamonti 87/1
# 4    Op. 2 No. 2  NaN  NaN   Biamonti 87/2
# 5    Op. 2 No. 3  NaN  NaN   Biamonti 87/3
# 6          Op. 3  NaN  NaN    Biamonti 105
# 7          Op. 4  NaN  NaN    Biamonti 115
# 8    Op. 5 No. 1  NaN  NaN  Biamonti 106/1
# 9    Op. 5 No. 2  NaN  NaN  Biamonti 106/2
# 10         Op. 6  NaN  NaN    Biamonti 134
# 11         Op. 7  NaN  NaN    Biamonti 136
# 12         Op. 8  NaN  NaN    Biamonti 135
# 13   Op. 9 No. 1  NaN  NaN  Biamonti 153/1
# 14   Op. 9 No. 2  NaN  NaN  Biamonti 153/2
# 15   Op. 9 No. 3  NaN  NaN  Biamonti 153/3
# 16  Op. 10 No. 1  NaN  NaN  Biamonti 157/1
# 17  Op. 10 No. 2  NaN  NaN  Biamonti 157/2
# 18  Op. 10 No. 3  NaN  NaN  Biamonti 157/3
# 19        Op. 11  NaN  NaN    Biamonti 156
#
# ...

# %% [markdown]
# ## df_fv_Biamonti_15_849.csv

# %%
df_2 = pd.read_csv('df_fv_Biamonti_15_849.csv')

# %%
df_2.rename(columns={'Scoring':'scoring', 'Genre':'genre'}, inplace=True)

# %%
df_2.head(5)
# Out:
#                                                title  Biamonti    year  \
# 0                         Song "Der Arme Componist"         15  1788.0
# 1  Cello part to the Lost Cadenza for Leopold Can...        16     NaN
# 2  Song "Meine Mutter fragt mich immer: trinkst du?"        43  1792.0
# 3                    Anglaise for piano for G minor         48  1792.0
# 4                                 Presto in F major        238  1800.0
#
#        key key_note  minor  WoO  Hess          name  Op.  Unv.  scoring  genre
# 0      NaN      NaN    NaN  NaN   NaN   Biamonti 15  NaN   NaN      NaN    NaN
# 1      NaN      NaN    NaN  NaN   NaN   Biamonti 16  NaN   NaN      NaN    NaN
# 2      NaN      NaN    NaN  NaN   NaN   Biamonti 43  NaN   NaN      NaN    NaN
# 3  G minor        G    1.0  NaN   NaN   Biamonti 48  NaN   NaN      NaN    NaN
# 4  F major        F    0.0  NaN   NaN  Biamonti 238  NaN   NaN      NaN    NaN

# %% [markdown]
# ## df_fv_Hess_3_335.csv

# %%
df_3 = pd.read_csv('df_fv_Hess_3_335.csv')

# %%
df_3.head()
# Out:
#                                                title  Hess    year  key  \
# 0            Twelve Ecossaise for piano or orchestra     3     NaN  NaN
# 1              Romance No. 3 for violin & orchestra     11  1816.0  NaN
# 2  Fragment of original version of Piano Concerto...    14  1794.0  NaN
# 3       Original introduction to the Choral Fantasy     16  1808.0  NaN
# 4                                       String Trio     25  1793.0  NaN
#
#   key_note  minor  Op.  WoO  Biamonti  Unv  Scoring  Genre     name
# 0      NaN    NaN  NaN  NaN       NaN  NaN      NaN    NaN   Hess 3
# 1      NaN    NaN  NaN  NaN       NaN  NaN      NaN    NaN  Hess 11
# 2      NaN    NaN  NaN  NaN       NaN  NaN      NaN    NaN  Hess 14
# 3      NaN    NaN  NaN  NaN       NaN  NaN      NaN    NaN  Hess 16
# 4      NaN    NaN  NaN  NaN       NaN  NaN      NaN    NaN  Hess 25

# %%
df_3.rename(columns={'Scoring':'scoring', 'Genre':'genre', 'Unv':'Unv.'}, inplace=True)

# %% [markdown]
# ## df_fv_Unv_1_23.csv

# %%
df_4 = pd.read_csv('df_fv_Unv_1_23.csv')

# %%
df_4.head()
# Out:
#                           title           key    year  Unv.  Biamonti   Hess  \
# 0           Symphony in C minor       C minor  1786.0     1       NaN  298.0
# 1  Sketches for a BACH Overture  B flat major  1822.0     4     832.0    NaN
# 2                   Concertante       D major  1802.0     5       NaN    NaN
# 3          Piano Concerto No. 6       D major  1814.0     6       NaN   15.0
# 4      Duo for Violin and Cello  E flat major  1792.0     8       NaN    NaN
#
#   key_note  Genre                  name  Op.  Scoring  WoO  minor
# 0        C    NaN              Hess 298  NaN      NaN  NaN      1
# 1   B flat    NaN  Unv. 4, Biamonti 832  NaN      NaN  NaN      0
# 2        D    NaN                Unv. 5  NaN      NaN  NaN      0
# 3        D    NaN               Hess 15  NaN      NaN  NaN      0
# 4   E flat    NaN                Unv. 8  NaN      NaN  NaN      0

# %%
df_4.rename(columns={'Scoring':'scoring', 'Genre':'genre'}, inplace=True)

# %% [markdown]
# ## df_fv_WoO_206_228.csv

# %%
df_5 = pd.read_csv('df_fv_WoO_206_228.csv')

# %%
df_5.head()
# Out:
#             key  year  WoO  Hess  \
# 0       F major  1792  206  12.0
# 1        E moll  1786  207  13.0
# 2  A flat major  1790  209  33.0
# 3       B minor  1817  210   NaN
# 4       C major  1790  211   NaN
#
#                                           Title  Biamonti  \
# 0                                 Oboe Concerto       NaN
# 1  Romance cantabile for soloists and orchestra       NaN
# 2                     Minuet for string quartet       NaN
# 3                 Allegretto for string quartet       NaN
# 4                                       Andante      52.0
#
#                    name key_note  minor  Op.  Unv.  Scoring  Genre
# 0               WoO 206        F    0.0  NaN   NaN      NaN    NaN
# 1               WoO 207        E    0.0  NaN   NaN      NaN    NaN
# 2               WoO 209   A flat    0.0  NaN   NaN      NaN    NaN
# 3               WoO 210        B    1.0  NaN   NaN      NaN    NaN
# 4  WoO 211, Biamonti 52        C    0.0  NaN   NaN      NaN    NaN

# %%
df_5.rename(columns={'Scoring':'scoring', 'Genre':'genre', 'Title':'title'}, inplace=True)

# %% [markdown]
# # Merge all 5 df

# %%
df = df_1.append(df_2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 564 entries, 0 to 35
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Op.       243 non-null    object
#  1   WoO       274 non-null    object
#  2   Hess      118 non-null    object
#  3   Biamonti  546 non-null    object
#  4   title     564 non-null    object
#  5   key       420 non-null    object
#  6   scoring   525 non-null    object
#  7   genre     527 non-null    object
#  8   name      564 non-null    object
#  9   year      553 non-null    float64
#  10  minor     420 non-null    float64
#  11  key_note  420 non-null    object
#  12  Unv.      0 non-null      float64
# dtypes: float64(3), object(10)
# memory usage: 61.7+ KB

# %%
df = df.append(df_3)

# %%
df = df.append(df_4)

# %%
df = df.append(df_5)

# %%
df.iloc[670:]
# Out:
#     Op.       WoO Hess Biamonti                                         title  \
# 0   NaN       206   12      NaN                                 Oboe Concerto
# 1   NaN       207   13      NaN  Romance cantabile for soloists and orchestra
# 2   NaN       209   33      NaN                     Minuet for string quartet
# 3   NaN       210  NaN      NaN                 Allegretto for string quartet
# 4   NaN       211  NaN       52                                       Andante
# 5   NaN       212   61      NaN                            Anglaise for piano
# 6   NaN  213 No.1  NaN      283                            Andante (bagatelle
# 7   NaN  213 No.2  NaN      282                            Finale (bagatelle)
# 8   NaN  213 No.3  NaN      275                             Rondo (bagatelle)
# 9   NaN       214   69      NaN                        Allegretto (bagatelle)
# 10  NaN       215   64      NaN                                        Fugue
# ...

# %% [markdown]
# # Check for dublicates

# %% [markdown]
# add column with value=1

# %%
df['one']= 1

# %% [markdown]
# ### Op.

# %%
df.groupby('Op.').sum().query('one!=1')
# Out:
#             year  minor  Unv.  one
# Op.
# Op. 121b  3646.0    0.0   0.0    2
# Op. 130   3651.0    0.0   0.0    2
# Op. 36    3607.0    0.0   0.0    2
# Op. 72    5425.0    0.0   0.0    3

# %%
df[df['Op.']=='Op. 121b']
# Out:
#           Op.  WoO Hess      Biamonti                             title  \
# 223  Op. 121b  NaN  NaN  Biamonti 766   Opferlied ("Die Flamme lodert")
# 224  Op. 121b  NaN  NaN  Biamonti 790   Opferlied ("Die Flamme lodert")
#
#          key       scoring  genre                    name    year  minor  \
# 223  E major   3vv ch orch  Vocal  Op. 121b, Biamonti 766  1822.0    0.0
# 224  E major   3vv ch orch  Vocal  Op. 121b, Biamonti 790  1824.0    0.0
#
#     key_note  Unv.  one
# 223        E   NaN    1
# 224        E   NaN    1

# %%
df[df['Op.']=='Op. 130']
# Out:
#          Op.  WoO Hess      Biamonti                  title           key  \
# 233  Op. 130  NaN  NaN  Biamonti 830   String Quartet No.13  B flat major
# 234  Op. 130  NaN  NaN  Biamonti 847   String Quartet No.13  B flat major
#
#         scoring    genre                   name    year  minor key_note  Unv.  \
# 233   2vn va vc  Chamber  Op. 130, Biamonti 830  1825.0    0.0   B flat   NaN
# 234   2vn va vc  Chamber  Op. 130, Biamonti 847  1826.0    0.0   B flat   NaN
#
#      one
# 233    1
# 234    1

# %%
df[df['Op.']=='Op. 36']
# Out:
#        Op.  WoO Hess      Biamonti           title      key    scoring  \
# 58  Op. 36  NaN  NaN  Biamonti 326   Symphony No.2  D major       orch
# 59  Op. 36  NaN  NaN  Biamonti 425   Symphony No.2  D major   vn vc pf
#
#          genre                  name    year  minor key_note  Unv.  one
# 58  Orchestral  Op. 36, Biamonti 326  1802.0    0.0        D   NaN    1
# 59     Chamber  Op. 36, Biamonti 425  1805.0    0.0        D   NaN    1

# %%
df[df['Op.']=='Op. 72']
# Out:
#         Op.  WoO      Hess      Biamonti  \
# 113  Op. 72  NaN  Hess 109  Biamonti 423
# 114  Op. 72  NaN  Hess 110  Biamonti 427
# 115  Op. 72  NaN       NaN  Biamonti 570
#
#                                                  title  key      scoring  \
# 113   Fidelio (Leonore  oder Der Triumph der ehelic...  NaN   vv ch orch
# 114   Fidelio (Leonore  oder Der Triumph der ehelic...  NaN   vv ch orch
# 115                           Fidelio  opera in 2 acts  NaN   vv ch orch
#
#      genre                  name    year  minor key_note  Unv.  one
# 113  Stage  Op. 72, Biamonti 423  1805.0    NaN      NaN   NaN    1
# 114  Stage  Op. 72, Biamonti 427  1806.0    NaN      NaN   NaN    1
# 115  Stage  Op. 72, Biamonti 570  1814.0    NaN      NaN   NaN    1

# %% [markdown]
# ### Biamonto

# %%
B_list = df.groupby('Biamonti').sum().query('one!=1')
B_list
# Out:
#                  year  minor  Unv.  one
# Biamonti
# Biamonti 125   3595.0    0.0   0.0    2
# Biamonti 39    3436.0    0.0   0.0    2
# Biamonti 423   3610.0    0.0   0.0    2
# Biamonti 427   3612.0    0.0   0.0    2
# Biamonti 431   3614.0    0.0   0.0    2
# Biamonti 44    3586.0    1.0   0.0    2
# Biamonti 525   3631.0    0.0   0.0    2
# Biamonti 531   5430.0    0.0   0.0    3
# Biamonti 652  10896.0    0.0   0.0    6
# Biamonti 696   3638.0    0.0   0.0    2
# Biamonti 742   5466.0    0.0   0.0    3
# Biamonti 775   3646.0    0.0   0.0    2
# Biamonti 80    7180.0    1.0   0.0    4
# Biamonti 830   3651.0    0.0   0.0    2
# Biamonti 84    3590.0    0.0   0.0    2

# %%
df[df['Biamonti']==B_list.index[14]]
# Out:
#      Op.           WoO Hess     Biamonti                              title  \
# 387  NaN  WoO 99 No. 8  NaN  Biamonti 84   Italian Partsongs:  O care selve
# 415  NaN       WoO 119  NaN  Biamonti 84                       O care selve
#
#          key scoring  genre                       name    year  minor  \
# 387  G major   v uch  Vocal  WoO 99 No. 8, Biamonti 84  1795.0    0.0
# 415  G major    v pf  Vocal       WoO 119, Biamonti 84  1795.0    0.0
#
#     key_note  Unv.  one
# 387        G   NaN    1
# 415        G   NaN    1

# %%
df[df['Biamonti']==B_list.index[1]]
# Out:
#      Op.     WoO Hess     Biamonti       title  key scoring    genre  \
# 284  NaN  WoO 27  NaN  Biamonti 39   Duets (3)  NaN   cl bn  Chamber
# 285  NaN  WoO 27  NaN  Biamonti 39   Duets (3)  NaN   vn vc  Chamber
#
#                     name    year  minor key_note  Unv.  one
# 284  WoO 27, Biamonti 39  1718.0    NaN      NaN   NaN    1
# 285  WoO 27, Biamonti 39  1718.0    NaN      NaN   NaN    1

# %%
df.drop(284,axis=0, inplace=True)

# %%
df[df['Biamonti']==B_list.index[4]]
# Out:
#         Op.  WoO Hess      Biamonti                 title      key  \
# 94   Op. 58  NaN  NaN  Biamonti 431   Piano Concerto No.4  G major
# 95  Op. 58a  NaN  NaN  Biamonti 431   Piano Concerto No.4  G major
#
#              scoring       genre                   name    year  minor  \
# 94           pf orch  Orchestral   Op. 58, Biamonti 431  1807.0    0.0
# 95   2vn va vc db pf     Chamber  Op. 58a, Biamonti 431  1807.0    0.0
#
#    key_note  Unv.  one
# 94        G   NaN    1
# 95        G   NaN    1

# %%
df.drop(95 ,axis=0, inplace=True)

# %%
df[df['Biamonti']==B_list.index[6]]
# Out:
#      Op.     WoO Hess      Biamonti                                    title  \
# 276  NaN  WoO 20  NaN  Biamonti 525   March ('Zapfenstreich') ('The Tattoo')
# 277  NaN  WoO 20  NaN  Biamonti 525   March ('Zapfenstreich') ('The Tattoo')
#
#          key      scoring       genre                  name    year  minor  \
# 276  C major   ww br perc  Orchestral  WoO 20, Biamonti 525  1809.0    0.0
# 277  C major   ww br perc  Orchestral  WoO 20, Biamonti 525  1822.0    0.0
#
#     key_note  Unv.  one
# 276        C   NaN    1
# 277        C   NaN    1

# %%
df.drop(277 ,axis=0, inplace=True)

# %%
df[df['Biamonti']==B_list.index[9]]
# Out:
#      Op.      WoO      Hess      Biamonti  \
# 399  NaN  WoO 105  Hess 124  Biamonti 696
# 400  NaN  WoO 105  Hess 125  Biamonti 696
#
#                                                  title      key      scoring  \
# 399   Hochzeitslied("Auf Freunde  singt dem Gott de...  A major   bass ch pf
# 400   Hochzeitslied("Auf Freunde  singt dem Gott de...  C major       uch pf
#
#      genre                   name    year  minor key_note  Unv.  one
# 399  Vocal  WoO 105, Biamonti 696  1819.0    0.0        A   NaN    1
# 400  Vocal  WoO 105, Biamonti 696  1819.0    0.0        C   NaN    1

# %%
df.drop(400 ,axis=0, inplace=True)

# %%
df[df['Biamonti']==B_list.index[11]]
# Out:
#      Op.      WoO Hess      Biamonti                        title  \
# 492  NaN  WoO 185  NaN  Biamonti 775   Edel sei der Mensch  canon
# 493  NaN  WoO 185  NaN  Biamonti 775   Edel sei der Mensch  canon
#
#               key scoring  genre                   name    year  minor  \
# 492       E major     6vv  Vocal  WoO 185, Biamonti 775  1823.0    0.0
# 493  E flat major     6vv  Vocal  WoO 185, Biamonti 775  1823.0    0.0
#
#     key_note  Unv.  one
# 492        E   NaN    1
# 493   E flat   NaN    1

# %%
df.drop(493 ,axis=0, inplace=True)

# %% [markdown]
# ### Hess

# %%
H_list = df.groupby('Hess').sum().query('one!=1')
H_list
# Out:
#             year  minor  Unv.  one
# Hess
# 46        3580.0    0.0  11.0    2
# 69        3588.0    2.0   0.0    2
# 303       1823.0    0.0   0.0    2
# Hess 117  3618.0    0.0   0.0    2
# Hess 118  7277.0    0.0   0.0    4

# %%
df[df['Hess']==H_list.index[0]]
# Out:
#     Op.  WoO Hess Biamonti                                 title      key  \
# 13  NaN  NaN   46      NaN  Violin Sonata in A major (fragment)   A major
# 8   NaN  NaN   46      NaN                         Violin Sonata  A major
#
#    scoring genre     name    year  minor key_note  Unv.  one
# 13     NaN   NaN  Hess 46  1790.0    0.0        A   NaN    1
# 8      NaN   NaN  Hess 46  1790.0    0.0        A  11.0    1

# %%
df.drop(13 ,axis=0, inplace=True)

# %% [markdown]
# ### WoO

# %%
W_list = df.groupby('WoO').sum().query('one!=1')
W_list
# Out:
#                  year  minor  Unv.  one
# WoO
# WoO 1          3582.0    0.0   0.0    2
# WoO 10         3590.0    0.0   0.0    2
# WoO 11         3598.0    0.0   0.0    2
# WoO 13         3594.0    0.0   0.0    2
# WoO 15         3604.0    0.0   0.0    2
# WoO 18         7252.0    0.0   0.0    4
# WoO 19         5442.0    0.0   0.0    3
# WoO 29         3596.0    0.0   0.0    2
# WoO 30         3624.0    0.0   0.0    2
# WoO 43b        1796.0    0.0   0.0    2
# WoO 53         3594.0    2.0   0.0    2
# WoO 7          3590.0    0.0   0.0    2
# WoO 8          3590.0    0.0   0.0    2
# WoO 99 No. 3a  3600.0    0.0   0.0    2
# WoO 99 No. 3b  3606.0    0.0   0.0    2
# WoO 99 No. 3c  3606.0    0.0   0.0    2

# %%
df[df['WoO']==W_list.index[8]]
# Out:
#      Op.     WoO Hess      Biamonti        title  key scoring    genre  \
# 289  NaN  WoO 30  NaN  Biamonti 548   Equali (3)  NaN    4tbn  Chamber
# 290  NaN  WoO 30  NaN           NaN   Equali (3)  NaN     mch  Chamber
#
#                      name    year  minor key_note  Unv.  one
# 289  WoO 30, Biamonti 548  1812.0    NaN      NaN   NaN    1
# 290                WoO 30  1812.0    NaN      NaN   NaN    1

# %%
df.drop(290 ,axis=0, inplace=True)

# %%
df[df['WoO']==W_list.index[9]]
# Out:
#      Op.      WoO     Hess      Biamonti    title           key    scoring  \
# 307  NaN  WoO 43b      NaN  Biamonti 122   Adagio  E flat major   mand hpd
# 308  NaN  WoO 43b  Hess 44  Biamonti 123   Adagio  E flat major   mand hpd
#
#        genre                   name    year  minor key_note  Unv.  one
# 307  Chamber  WoO 43b, Biamonti 122  1796.0    0.0   E flat   NaN    1
# 308  Chamber  WoO 43b, Biamonti 123     NaN    0.0   E flat   NaN    1

# %%
df.drop(308 ,axis=0, inplace=True)

# %%
df[df['WoO']==W_list.index[13]]
# Out:
#      Op.            WoO      Hess      Biamonti  \
# 373  NaN  WoO 99 No. 3a       NaN  Biamonti 142
# 374  NaN  WoO 99 No. 3a  Hess 208  Biamonti 143
#
#                                       title  key scoring  genre  \
# 373   Italian Partsongs:  Fra tutte le pene  NaN     2vv  Vocal
# 374   Italian Partsongs:  Fra tutte le pene  NaN     2vv  Vocal
#
#                             name    year  minor key_note  Unv.  one
# 373  WoO 99 No. 3a, Biamonti 142  1797.0    NaN      NaN   NaN    1
# 374  WoO 99 No. 3a, Biamonti 143  1803.0    NaN      NaN   NaN    1

# %%
df.drop(373 ,axis=0, inplace=True)

# %%
df[df['WoO']==W_list.index[14]]
# Out:
#      Op.            WoO      Hess      Biamonti  \
# 375  NaN  WoO 99 No. 3b  Hess 225  Biamonti 144
# 376  NaN  WoO 99 No. 3b  Hess 209  Biamonti 145
#
#                                       title  key scoring  genre  \
# 375   Italian Partsongs:  Fra tutte le pene  NaN     2vv  Vocal
# 376   Italian Partsongs:  Fra tutte le pene  NaN     2vv  Vocal
#
#                             name    year  minor key_note  Unv.  one
# 375  WoO 99 No. 3b, Biamonti 144  1803.0    NaN      NaN   NaN    1
# 376  WoO 99 No. 3b, Biamonti 145  1803.0    NaN      NaN   NaN    1

# %% [markdown]
# ### Unv.

# %%
df.groupby('Unv.').sum()
# Out:
#         year  minor  one
# Unv.
# 1.0   1786.0    1.0    1
# 4.0   1822.0    0.0    1
# 5.0   1802.0    0.0    1
# 6.0   1814.0    0.0    1
# 8.0   1792.0    0.0    1
# 9.0   1790.0    0.0    1
# 10.0  1816.0    1.0    1
# 11.0  1790.0    0.0    1
# 12.0  1793.0    0.0    1
# 13.0  1797.0    0.0    1
# 14.0  1794.0    0.0    1
# 15.0  1803.0    0.0    1
# 16.0  1808.0    0.0    1
# 17.0  1814.0    0.0    1
# 19.0  1790.0    0.0    1
# 20.0     0.0    0.0    1
# 21.0  1790.0    0.0    1
# 22.0  1796.0    0.0    1
# 23.0  1796.0    0.0    1

# %% [markdown]
# ### symphony

# %%
df[df['title'].str.contains('Symphony')]
# Out:
#          Op.  WoO Hess      Biamonti  \
# 38    Op. 21  NaN  NaN  Biamonti 203
# 58    Op. 36  NaN  NaN  Biamonti 326
# 59    Op. 36  NaN  NaN  Biamonti 425
# 91    Op. 55  NaN  NaN  Biamonti 406
# 99    Op. 60  NaN  NaN  Biamonti 429
# 107   Op. 67  NaN  NaN  Biamonti 443
# 108   Op. 68  NaN  NaN  Biamonti 453
# 148   Op. 91  NaN  NaN  Biamonti 560
# 149   Op. 92  NaN  NaN  Biamonti 544
# 150   Op. 93  NaN  NaN  Biamonti 659
# 228  Op. 125  NaN  NaN  Biamonti 787
# 527      NaN  NaN  NaN  Biamonti 838
# 25       NaN  NaN  NaN           547
# 42       NaN  NaN   96           NaN
# 0        NaN  NaN  298           NaN
#
#                                                  title           key  \
# 38                                       Symphony No.1       C major
# 58                                       Symphony No.2       D major
# 59                                       Symphony No.2       D major
# 91                            Symphony No.3 ('Eroica')  E flat major
# ...

# %% [markdown]
# ### other dublicates

# %%
df[df['title'].str.contains('13')]
# Out:
#               Op.     WoO Hess        Biamonti  \
# 44   Op. 27 No. 1     NaN  NaN  Biamonti 297/1
# 233       Op. 130     NaN  NaN    Biamonti 830
# 234       Op. 130     NaN  NaN    Biamonti 847
# 336           NaN  WoO 66  NaN     Biamonti 37
#
#                                                  title           key  \
# 44    Piano Sonatas : Piano Sonata No.13 ('Quasi un...  E flat major
# 233                               String Quartet No.13  B flat major
# 234                               String Quartet No.13  B flat major
# 336   Variations on 'Es war einmal ein alter Mann'(13)       A major
#
#         scoring     genre                          name    year  minor  \
# 44           pf  Keyboard  Op. 27 No. 1, Biamonti 297/1  1801.0    0.0
# 233   2vn va vc   Chamber         Op. 130, Biamonti 830  1825.0    0.0
# 234   2vn va vc   Chamber         Op. 130, Biamonti 847  1826.0    0.0
# 336          pf  Keyboard           WoO 66, Biamonti 37  1792.0    0.0
#
# ...

# %%
df.drop(234 ,axis=0, inplace=True)

# %% [markdown]
# # Check that all NaN is np.nan

# %%
df[df['Op.'].isna()]
# Out:
#      Op.       WoO      Hess      Biamonti  \
# 243  NaN     WoO 1       NaN   Biamonti 29
# 244  NaN     WoO 1   Hess 89   Biamonti 30
# 245  NaN     WoO 2       NaN           NaN
# 246  NaN    WoO 2a  Hess 117  Biamonti 553
# 247  NaN    WoO 2b  Hess 117  Biamonti 554
# ..   ...       ...       ...           ...
# 21   NaN       225       303           NaN
# 22   NaN       226       260           NaN
# 23   NaN       227       277           NaN
# 24   NaN  228 No.1       NaN           NaN
# 25   NaN  228 No.2       285           NaN
#
#                                                  title      key scoring  \
# 243                        Musik zu einem Ritterballet  D major    orch
# 244                        Musik zu einem Ritterballet  D major      pf
# 245   Tarpeja  music for Christoph Kuffner's drama ...      NaN    orch
# 246                                    Triumphal March  C major    orch
# 247                                  Prelude to Act II  D major    orch
# ...

# %%
df[df['Op.']=='nan']
# Out:
# Empty DataFrame
# Columns: [Op., WoO, Hess, Biamonti, title, key, scoring, genre, name, year, minor, key_note, Unv., one]
# Index: []

# %% [markdown]
# ## key

# %%
df[df['key'].isna()]
# Out:
#        Op.       WoO Hess      Biamonti  \
# 54  Op. 32       NaN  NaN  Biamonti 421
# 55  Op. 33       NaN  NaN  Biamonti 334
# 66  Op. 43       NaN  NaN  Biamonti 288
# 68  Op. 45       NaN  NaN  Biamonti 377
# 80  Op. 51       NaN  NaN           NaN
# ..     ...       ...  ...           ...
# 17     NaN       221  276           NaN
# 21     NaN       225  303           NaN
# 22     NaN       226  260           NaN
# 24     NaN  228 No.1  NaN           NaN
# 25     NaN  228 No.2  285           NaN
#
#                                                 title  key scoring     genre  \
# 54   An die Hoffnung ("Die du so gern in heilgen N...  NaN    v pf     Vocal
# 55                                     Bagatelles (7)  NaN      pf  Keyboard
# 66   Die Geschöpfe des Prometheus (The Creatures o...  NaN    orch     Stage
# 68                                        Marches (3)  NaN    pf4h  Keyboard
# 80                                         Rondos (2)  NaN      pf  Keyboard
# ...

# %%
df.groupby('key').sum()['one']
# Out:
# key
#  C major          1
# A flat major      7
# A major          34
# A minor           6
# B flat major     43
# B flat minor      1
# B minor           3
# C major          78
# C minor          31
# C sharp minor     2
# D major          56
# D minor           9
# Dflat major       1
# E flat major     65
# E major          15
# E minor           4
# E moll            1
# F major          50
# F minor           9
# F sharp major     1
# F sharp minor     1
# G major          48
# G minor           8
# Name: one, dtype: int64

# %%
df.groupby('key').sum()['one'].sum()
# Out:
# 474

# %%
df[df['key']=='NaN']
# Out:
# Empty DataFrame
# Columns: [Op., WoO, Hess, Biamonti, title, key, scoring, genre, name, year, minor, key_note, Unv., one]
# Index: []

# %%
df[df['key']=='Dflat major']
# Out:
#    Op.       WoO Hess Biamonti               title          key scoring genre  \
# 6  NaN  213 No.1  NaN      283  Andante (bagatelle  Dflat major     NaN   NaN
#
#                          name    year  minor key_note  Unv.  one
# 6  WoO 213 No.1, Biamonti 283  1793.0    0.0    Dflat   NaN    1

# %%
df.loc[df['key']=='Dflat major',['key']] = 'C sharp major'

# %%
df.loc[df['WoO']=='213 No.1',['key_note']] = 'C sharp'

# %%
df[df['WoO']=='213 No.1']
# Out:
#    Op.       WoO Hess Biamonti               title            key scoring  \
# 6  NaN  213 No.1  NaN      283  Andante (bagatelle  C sharp major     NaN
#
#   genre                        name    year  minor key_note  Unv.  one
# 6   NaN  WoO 213 No.1, Biamonti 283  1793.0    0.0  C sharp   NaN    1

# %% [markdown]
# # Minor as category (word)

# %%
def minor_as_word(num):

    if num==1:
        return 'minor'
    elif num==0:
        return 'major'
    
    return 'unknown key'

# %%
df['major-minor'] = df['minor'].apply(minor_as_word)

# %%
df[df['key'].isna()]
# Out:
#        Op.       WoO Hess      Biamonti  \
# 54  Op. 32       NaN  NaN  Biamonti 421
# 55  Op. 33       NaN  NaN  Biamonti 334
# 66  Op. 43       NaN  NaN  Biamonti 288
# 68  Op. 45       NaN  NaN  Biamonti 377
# 80  Op. 51       NaN  NaN           NaN
# ..     ...       ...  ...           ...
# 17     NaN       221  276           NaN
# 21     NaN       225  303           NaN
# 22     NaN       226  260           NaN
# 24     NaN  228 No.1  NaN           NaN
# 25     NaN  228 No.2  285           NaN
#
#                                                 title  key scoring     genre  \
# 54   An die Hoffnung ("Die du so gern in heilgen N...  NaN    v pf     Vocal
# 55                                     Bagatelles (7)  NaN      pf  Keyboard
# 66   Die Geschöpfe des Prometheus (The Creatures o...  NaN    orch     Stage
# 68                                        Marches (3)  NaN    pf4h  Keyboard
# 80                                         Rondos (2)  NaN      pf  Keyboard
# ...

# %%
df['major-minor'].unique()
# Out:
# array(['major', 'minor', 'unknown key'], dtype=object)

# %%
df['major-minor'].nunique()
# Out:
# 3

# %%
df['major-minor'].value_counts()
# Out:
# major          405
# unknown key    202
# minor           75
# Name: major-minor, dtype: int64

# %% [markdown]
# ### nan in key as unknown

# %%
df['key'].unique()
# Out:
# array(['E flat major', 'G major', 'C minor', 'F minor', 'A major',
#        'C major', 'F major', 'G minor', 'D major', 'B flat major',
#        'E major', 'A minor', 'A flat major', 'C sharp minor', 'D minor',
#        nan, 'F sharp minor', 'E minor', 'F sharp major', 'B flat minor',
#        'B minor', 'E moll', 'C sharp major', ' C major'], dtype=object)

# %%
df.loc[df['key'].isna(),['key']]='unknown'

# %%
df.loc[df['key_note'].isna(),['key_note']]='unknown'

# %% [markdown]
# ## Change year

# %%
np.sort(df['year'].unique())
# Out:
# array([1718., 1781., 1782., 1783., 1784., 1785., 1786., 1788., 1789.,
#        1790., 1791., 1792., 1793., 1794., 1795., 1796., 1797., 1798.,
#        1799., 1800., 1801., 1802., 1803., 1804., 1805., 1806., 1807.,
#        1808., 1809., 1810., 1811., 1812., 1813., 1814., 1815., 1816.,
#        1817., 1818., 1819., 1820., 1821., 1822., 1823., 1824., 1825.,
#        1826., 1827.,   nan])

# %%
df.loc[df['year']==1781,['year']]=np.nan

# %% [markdown]
# # Genre

# %%
df['genre'].value_counts()
# Out:
# Vocal               226
# Chamber             117
# Keyboard            101
# Orchestral           50
# Stage                19
# Keyboard/Chamber      1
# Keyboard/Vocal        1
# Quintets              1
# Chanber               1
# Name: genre, dtype: int64

# %%
df.loc[df['genre']=='Chanber',['genre']] = 'Chamber'

# %%
df.loc[df['genre']=='Keyboard/Chamber',['genre']] ='Keyboard'

# %%
df.loc[df['genre']=='Keyboard/Vocal',['genre']] ='Vocal'

# %%
df.loc[df['genre']=='Quintets',['genre']] ='Chamber'

# %%
df['genre'].value_counts()
# Out:
# Vocal         227
# Chamber       119
# Keyboard      102
# Orchestral     50
# Stage          19
# Name: genre, dtype: int64

# %% [markdown]
# unknown genre

# %%
df[df['genre'].isna()==True]['major-minor'].count()
# Out:
# 165

# %% [markdown]
# known genre

# %%
df['genre'].count()
# Out:
# 517

# %% [markdown]
# ## delete stage genre

# %%
df[df['genre']=='Stage']
# Out:
#          Op.           WoO      Hess        Biamonti  \
# 66    Op. 43           NaN       NaN    Biamonti 288
# 113   Op. 72           NaN  Hess 109    Biamonti 423
# 114   Op. 72           NaN  Hess 110    Biamonti 427
# 115   Op. 72           NaN       NaN    Biamonti 570
# 141   Op. 84           NaN       NaN    Biamonti 518
# 214  Op. 113           NaN  Hess 118    Biamonti 539
# 215  Op. 114           NaN  Hess 118    Biamonti 742
# 218  Op. 117           NaN       NaN    Biamonti 538
# 243      NaN         WoO 1       NaN     Biamonti 29
# 244      NaN         WoO 1   Hess 89     Biamonti 30
# 245      NaN         WoO 2       NaN             NaN
# 246      NaN        WoO 2a  Hess 117    Biamonti 553
# 247      NaN        WoO 2b  Hess 117    Biamonti 554
# 361      NaN  WoO 91 No. 1       NaN  Biamonti 119/1
# 362      NaN  WoO 91 No. 2       NaN  Biamonti 119/2
# 366      NaN        WoO 94       NaN    Biamonti 568
# 368      NaN        WoO 96       NaN    Biamonti 595
# ...

# %% [markdown]
# ### fidelio

# %%
df[df['title'].str.lower().str.contains('fidelio')]
# Out:
#         Op.  WoO      Hess      Biamonti  \
# 113  Op. 72  NaN  Hess 109  Biamonti 423
# 114  Op. 72  NaN  Hess 110  Biamonti 427
# 115  Op. 72  NaN       NaN  Biamonti 570
#
#                                                  title      key      scoring  \
# 113   Fidelio (Leonore  oder Der Triumph der ehelic...  unknown   vv ch orch
# 114   Fidelio (Leonore  oder Der Triumph der ehelic...  unknown   vv ch orch
# 115                           Fidelio  opera in 2 acts  unknown   vv ch orch
#
#      genre                  name    year  minor key_note  Unv.  one  \
# 113  Stage  Op. 72, Biamonti 423  1805.0    NaN  unknown   NaN    1
# 114  Stage  Op. 72, Biamonti 427  1806.0    NaN  unknown   NaN    1
# 115  Stage  Op. 72, Biamonti 570  1814.0    NaN  unknown   NaN    1
#
#      major-minor
# 113  unknown key
# 114  unknown key
# 115  unknown key

# %%
df.loc[df['title'].str.lower().str.contains('fidelio'),['genre']]='Vocal'

# %%
df.loc[df['WoO']=='WoO 91 No. 1',['genre']]='Vocal'

# %%
df.loc[df['WoO']=='WoO 91 No. 2',['genre']]='Vocal'

# %%
df.loc[df['WoO']=='WoO 94',['genre']]='Vocal'

# %%
df.loc[df['WoO']=='WoO 97',['genre']]='Vocal'

# %%
df[df['genre']=='Stage']
# Out:
#          Op.     WoO      Hess      Biamonti  \
# 66    Op. 43     NaN       NaN  Biamonti 288
# 141   Op. 84     NaN       NaN  Biamonti 518
# 214  Op. 113     NaN  Hess 118  Biamonti 539
# 215  Op. 114     NaN  Hess 118  Biamonti 742
# 218  Op. 117     NaN       NaN  Biamonti 538
# 243      NaN   WoO 1       NaN   Biamonti 29
# 244      NaN   WoO 1   Hess 89   Biamonti 30
# 245      NaN   WoO 2       NaN           NaN
# 246      NaN  WoO 2a  Hess 117  Biamonti 553
# 247      NaN  WoO 2b  Hess 117  Biamonti 554
# 368      NaN  WoO 96       NaN  Biamonti 595
# 370      NaN  WoO 98  Hess 118  Biamonti 742
#
#                                                  title           key  \
# 66    Die Geschöpfe des Prometheus (The Creatures o...       unknown
# 141                                             Egmont       unknown
# 214   Die Ruinen von Athen (The Ruins of Athens)  m...       unknown
# 215   Die Ruinen von Athen (The Ruins of Athens)  m...       unknown
# ...

# %% [markdown]
# rest as Orchestral

# %%
df.loc[df['genre']=='Stage',['genre']]='Orchestral'

# %%
df['genre'].value_counts()
# Out:
# Vocal         234
# Chamber       119
# Keyboard      102
# Orchestral     62
# Name: genre, dtype: int64

# %% [markdown]
# ## guess unknown genre

# %%
df[df['genre'].isna()]
# Out:
#      Op.       WoO          Hess      Biamonti  \
# 294  NaN   WoO 33b  Hess 106-107  Biamonti NaN
# 0    NaN       NaN           NaN            15
# 1    NaN       NaN           NaN            16
# 2    NaN       NaN           NaN            43
# 3    NaN       NaN           NaN            48
# ..   ...       ...           ...           ...
# 21   NaN       225           303           NaN
# 22   NaN       226           260           NaN
# 23   NaN       227           277           NaN
# 24   NaN  228 No.1           NaN           NaN
# 25   NaN  228 No.2           285           NaN
#
#                                                  title      key scoring genre  \
# 294                                         Pieces (2)  unknown     NaN   NaN
# 0                           Song "Der Arme Componist"   unknown     NaN   NaN
# 1    Cello part to the Lost Cadenza for Leopold Can...  unknown     NaN   NaN
# 2    Song "Meine Mutter fragt mich immer: trinkst du?"  unknown     NaN   NaN
# ...

# %% [markdown]
# ### orchestral

# %%
df[(df['title'].str.lower().str.contains('orchestra')) & df['genre'].isna()]
# Out:
#    Op.  WoO Hess Biamonti                                         title  \
# 5  NaN  NaN  NaN      249              Minuet for orchestra in D major
# 6  NaN  NaN  NaN      252              Minuet for orchestra in D major
# 0  NaN  NaN    3      NaN       Twelve Ecossaise for piano or orchestra
# 1  NaN  NaN   11      NaN         Romance No. 3 for violin & orchestra
# 1  NaN  207   13      NaN  Romance cantabile for soloists and orchestra
#
#        key scoring genre          name    year  minor key_note  Unv.  one  \
# 5  D major     NaN   NaN  Biamonti 249  1800.0    0.0        D   NaN    1
# 6  D major     NaN   NaN  Biamonti 252  1800.0    0.0        D   NaN    1
# 0  unknown     NaN   NaN        Hess 3     NaN    NaN  unknown   NaN    1
# 1  unknown     NaN   NaN       Hess 11  1816.0    NaN  unknown   NaN    1
# 1   E moll     NaN   NaN       WoO 207  1786.0    0.0        E   NaN    1
#
#    major-minor
# 5        major
# 6        major
# 0  unknown key
# 1  unknown key
# ...

# %%
df.loc[(df['title'].str.lower().str.contains('orchestra')) & df['genre'].isna(),['genre']]='Orchestral'

# %%
df.loc[df['Hess']==96,['genre']] = 'Orchestral'

# %%
df[(df['title'].str.lower().str.contains('symphony')) & df['genre'].isna()]
# Out:
#     Op.  WoO Hess Biamonti                                              title  \
# 12  NaN  NaN  NaN      291                            Andante for a symphony
# 25  NaN  NaN  NaN      547  Symphony No. 8 with the original ending of Hes...
# 0   NaN  NaN  298      NaN                                Symphony in C minor
#
#         key scoring genre          name    year  minor key_note  Unv.  one  \
# 12  unknown     NaN   NaN  Biamonti 291  1801.0    NaN  unknown   NaN    1
# 25  unknown     NaN   NaN  Biamonti 547  1812.0    NaN  unknown   NaN    1
# 0   C minor     NaN   NaN      Hess 298  1786.0    1.0        C   1.0    1
#
#     major-minor
# 12  unknown key
# 25  unknown key
# 0         minor

# %%
df.loc[(df['title'].str.lower().str.contains('symphony')) & (df['genre'].isna()),['genre']]='Orchestral'

# %%
df.loc[(df['title'].str.lower().str.contains('concerto')) & df['genre'].isna(),['genre']] = 'Orchestral'

# %% [markdown]
# ### Vocal

# %%
df.loc[(df['title'].str.lower().str.contains('song')) & df['genre'].isna(),['genre']]='Vocal'

# %%
df[(df['title'].str.lower().str.contains('gesänge')) & df['genre'].isna()]
# Out:
# Empty DataFrame
# Columns: [Op., WoO, Hess, Biamonti, title, key, scoring, genre, name, year, minor, key_note, Unv., one, major-minor]
# Index: []

# %%
df[(df['title'].str.lower().str.contains('lied')) & df['genre'].isna()]
# Out:
#     Op.  WoO Hess Biamonti                                              title  \
# 18  NaN  NaN   54      NaN         Piano variations on Freudvoll und Liedvoll
# 23  NaN  NaN   63      NaN  Arrangement of Christian Friedrich Daniel Schu...
# 16  NaN  220  123      NaN        Kriegslied für die verbündeten Heere (lost)
#
#         key scoring genre     name    year  minor key_note  Unv.  one  \
# 18  unknown     NaN   NaN  Hess 54     NaN    NaN  unknown   NaN    1
# 23  unknown     NaN   NaN  Hess 63  1789.0    NaN  unknown   NaN    1
# 16  unknown     NaN   NaN  WoO 220  1813.0    NaN  unknown   NaN    1
#
#     major-minor
# 18  unknown key
# 23  unknown key
# 16  unknown key

# %%
df[(df['title'].str.lower().str.contains('cantat')) & df['genre'].isna()]
# Out:
#     Op.  WoO Hess Biamonti                                              title  \
# 1   NaN  NaN  NaN       16  Cello part to the Lost Cadenza for Leopold Can...
# 66  NaN  NaN  314      NaN                                   Funeral Cantata
# 14  NaN  NaN  317      NaN                  Cantata Europens Befreiungsstunde
# 15  NaN  NaN  NaN      NaN                        Cantata for voice and piano
#
#              key scoring genre         name    year  minor key_note  Unv.  \
# 1        unknown     NaN   NaN  Biamonti 16     NaN    NaN  unknown   NaN
# 66       unknown     NaN   NaN     Hess 314     NaN    NaN  unknown   NaN
# 14       unknown     NaN   NaN     Hess 317  1814.0    0.0  unknown  17.0
# 15  B flat major     NaN   NaN      Unv. 19  1790.0    0.0   B flat  19.0
#
#     one  major-minor
# 1     1  unknown key
# 66    1  unknown key
# 14    1        major
# 15    1        major

# %%
df.loc[(df['title'].str.lower().str.contains('cantat')) & df['genre'].isna(),['genre']]='Vocal'

# %%
df.loc[df['Hess']==123,['genre']] = 'Vocal'

# %% [markdown]
# ### chamber

# %%
df.loc[(df['title'].str.lower().str.contains('duo')) & df['genre'].isna(),['genre']]='Chamber'

# %%
df.loc[(df['title'].str.lower().str.contains('trio')) & df['genre'].isna(),['genre']]='Chamber'

# %%
df.loc[(df['title'].str.lower().str.contains('quartet')) & (df['genre'].isna()),['genre']]='Chamber'

# %%
df.loc[(df['title'].str.lower().str.contains('quintet')) & (df['genre'].isna()),['genre']]='Chamber'

# %%
df.loc[df['Biamonti']==389,['genre']]='Chamber'

# %%
df.loc[df['Biamonti']==606,['genre']]='Chamber'

# %%
df.loc[df['Hess']==297,['genre']]='Chamber'

# %%
df.loc[df['Hess']==46,['genre']]='Chamber'

# %% [markdown]
# ### keyboard

# %%
df[(df['title'].str.lower().str.contains('piano')) & df['genre'].isna()]
# Out:
#     Op.       WoO Hess Biamonti  \
# 3   NaN       NaN  NaN       48
# 7   NaN       NaN  NaN      269
# 8   NaN       NaN  NaN      272
# 10  NaN       NaN  NaN      277
# 11  NaN       NaN  NaN      279
# 14  NaN       NaN  NaN      319
# 15  NaN       NaN  NaN      322
# 16  NaN       NaN  NaN      323
# 17  NaN       NaN  NaN      346
# 18  NaN       NaN  NaN      347
# 21  NaN       NaN  NaN      383
# 23  NaN       NaN  NaN      392
# 24  NaN       NaN  NaN      447
# 27  NaN       NaN  NaN      621
# 28  NaN       NaN  NaN      622
# 32  NaN       NaN  NaN      638
# 35  NaN       NaN  NaN      849
# 10  NaN       NaN   37      NaN
# 17  NaN       NaN   52      NaN
# 18  NaN       NaN   54      NaN
# 20  NaN       NaN   58      NaN
# 21  NaN       NaN   59      NaN
# 22  NaN       NaN   60      NaN
# 23  NaN       NaN   63      NaN
# 25  NaN       NaN   67      NaN
# 26  NaN       NaN   69      NaN
# 27  NaN       NaN   70      NaN
# 28  NaN       NaN   71      NaN
# ...

# %%
df.loc[(df['title'].str.lower().str.contains('piano')) & df['genre'].isna(),['genre']]='Keyboard'

# %% [markdown]
# ## genre information from wikipedia

# %%
df.loc[df['Hess']==73,'genre']='Keyboard'

# %% [markdown]
# ### genre guessing results

# %%
df[df['genre'].isna()]
# Out:
#      Op.       WoO          Hess      Biamonti  \
# 294  NaN   WoO 33b  Hess 106-107  Biamonti NaN
# 4    NaN       NaN           NaN           238
# 19   NaN       NaN           NaN           359
# 29   NaN       NaN           NaN           624
# 34   NaN       NaN           NaN           811
# 3    NaN       NaN            16           NaN
# 19   NaN       NaN            57           NaN
# 45   NaN       NaN           108           NaN
# 46   NaN       NaN           116           NaN
# 47   NaN       NaN           254           NaN
# 48   NaN       NaN           274           NaN
# 49   NaN       NaN           296           NaN
# 51   NaN       NaN           299           NaN
# 52   NaN       NaN           300           NaN
# 53   NaN       NaN           301           NaN
# 54   NaN       NaN           302           NaN
# 55   NaN       NaN           303           NaN
# 56   NaN       NaN           304           NaN
# 57   NaN       NaN           305           NaN
# ...

# %%
df[df['genre'].isna()].count()
# Out:
# Op.             0
# WoO            19
# Hess           41
# Biamonti       13
# title          57
# key            57
# scoring         0
# genre           0
# name           57
# year           37
# minor          28
# key_note       57
# Unv.            5
# one            57
# major-minor    57
# dtype: int64

# %%
df['genre'].value_counts()
# Out:
# Vocal         248
# Keyboard      153
# Chamber       149
# Orchestral     75
# Name: genre, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 682 entries, 0 to 25
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Op.          240 non-null    object
#  1   WoO          292 non-null    object
#  2   Hess         226 non-null    object
#  3   Biamonti     546 non-null    object
#  4   title        682 non-null    object
#  5   key          682 non-null    object
#  6   scoring      515 non-null    object
#  7   genre        625 non-null    object
#  8   name         682 non-null    object
#  9   year         640 non-null    float64
#  10  minor        480 non-null    float64
#  11  key_note     682 non-null    object
#  12  Unv.         19 non-null     float64
#  13  one          682 non-null    int64
#  14  major-minor  682 non-null    object
# dtypes: float64(3), int64(1), object(11)
# memory usage: 85.2+ KB

# %% [markdown]
# # Create new property - type

# %%
df['type']=np.nan

# %%
pd.set_option('display.max_rows',None)

# %% [markdown]
# ## Sonatas

# %% [markdown]
# ### Sonatas for piano

# %%
df.loc[df['title'].str.lower().str.contains('sonata') & df['title'].str.lower().str.contains('piano'),['type']] = 'Sonata for Piano'

# %% [markdown]
# ### Sonata for violin

# %%
df.loc[df['title'].str.lower().str.contains('sonata') & df['title'].str.lower().str.contains('violin'),['type']] = 'Sonata for Violin'

# %%
df[df['type']=='Sonata for Violin']
# Out:
#               Op.  WoO Hess        Biamonti  \
# 20   Op. 12 No. 1  NaN  NaN  Biamonti 165/1
# 21   Op. 12 No. 2  NaN  NaN  Biamonti 165/2
# 22   Op. 12 No. 3  NaN  NaN  Biamonti 165/3
# 40         Op. 23  NaN  NaN    Biamonti 293
# 41         Op. 24  NaN  NaN    Biamonti 294
# 48   Op. 30 No. 1  NaN  NaN  Biamonti 340/1
# 49   Op. 30 No. 2  NaN  NaN  Biamonti 340/2
# 50   Op. 30 No. 3  NaN  NaN  Biamonti 340/3
# 70         Op. 47  NaN  NaN    Biamonti 366
# 153        Op. 96  NaN  NaN    Biamonti 550
# 8             NaN  NaN   46             NaN
#
#                                                title           key scoring  \
# 20               Violin Sonatas : Violin Sonata No.1       D major   vn pf
# 21               Violin Sonatas : Violin Sonata No.2       A major   vn pf
# 22               Violin Sonatas : Violin Sonata No.3  E flat major   vn pf
# 40                                Violin Sonata No.4       A minor   vn pf
# ...

# %% [markdown]
# ### Sonata for other instr

# %%
df.loc[df['title'].str.lower().str.contains('sonata') & df['type'].isna(),['type']] = 'Sonata for other instruments'

# %% [markdown]
# ## Symphony

# %%
df[df['title'].str.lower().str.contains('symphony')]
# Out:
#          Op.  WoO Hess      Biamonti  \
# 38    Op. 21  NaN  NaN  Biamonti 203
# 58    Op. 36  NaN  NaN  Biamonti 326
# 59    Op. 36  NaN  NaN  Biamonti 425
# 91    Op. 55  NaN  NaN  Biamonti 406
# 99    Op. 60  NaN  NaN  Biamonti 429
# 107   Op. 67  NaN  NaN  Biamonti 443
# 108   Op. 68  NaN  NaN  Biamonti 453
# 148   Op. 91  NaN  NaN  Biamonti 560
# 149   Op. 92  NaN  NaN  Biamonti 544
# 150   Op. 93  NaN  NaN  Biamonti 659
# 228  Op. 125  NaN  NaN  Biamonti 787
# 527      NaN  NaN  NaN  Biamonti 838
# 12       NaN  NaN  NaN           291
# 25       NaN  NaN  NaN           547
# 42       NaN  NaN   96           NaN
# 0        NaN  NaN  298           NaN
#
#                                                  title           key  \
# 38                                       Symphony No.1       C major
# 58                                       Symphony No.2       D major
# 59                                       Symphony No.2       D major
# ...

# %%
df.loc[(df['title'].str.lower().str.contains('symphony')) & (df['genre'].isna()==False),['type']] = 'Symphony'

# %%
df[df['Op.']=='Op. 125']
# Out:
#          Op.  WoO Hess      Biamonti           title      key  \
# 228  Op. 125  NaN  NaN  Biamonti 787   Symphony No.9  D minor
#
#                   scoring  genre                   name    year  minor  \
# 228   sop alt ten bass ch  Vocal  Op. 125, Biamonti 787  1824.0    1.0
#
#     key_note  Unv.  one major-minor      type
# 228        D   NaN    1       minor  Symphony

# %%
df.loc[df['Op.']=='Op. 125',['genre']]='Orchestral'

# %%
df[df['Op.']=='Op. 36']
# Out:
#        Op.  WoO Hess      Biamonti           title      key    scoring  \
# 58  Op. 36  NaN  NaN  Biamonti 326   Symphony No.2  D major       orch
# 59  Op. 36  NaN  NaN  Biamonti 425   Symphony No.2  D major   vn vc pf
#
#          genre                  name    year  minor key_note  Unv.  one  \
# 58  Orchestral  Op. 36, Biamonti 326  1802.0    0.0        D   NaN    1
# 59     Chamber  Op. 36, Biamonti 425  1805.0    0.0        D   NaN    1
#
#    major-minor      type
# 58       major  Symphony
# 59       major  Symphony

# %% [markdown]
# ## Concerto

# %%
df[df['title'].str.lower().str.contains('concerto')]
# Out:
#          Op.    WoO     Hess      Biamonti  \
# 26    Op. 15    NaN      NaN  Biamonti 167
# 36    Op. 19    NaN      NaN  Biamonti 166
# 60    Op. 37    NaN      NaN  Biamonti 337
# 92    Op. 56    NaN      NaN  Biamonti 410
# 94    Op. 58    NaN      NaN  Biamonti 431
# 100   Op. 61    NaN      NaN  Biamonti 432
# 101  Op. 61a    NaN      NaN  Biamonti 441
# 118   Op. 73    NaN      NaN  Biamonti 499
# 249      NaN  WoO 4      NaN   Biamonti 10
# 250      NaN  WoO 5  Hess 10   Biamonti 33
# 2        NaN    NaN       14           NaN
# 24       NaN    NaN       65           NaN
# 3        NaN    NaN       15           NaN
# 0        NaN    206       12           NaN
#
#                                                  title           key  \
# 26                                 Piano Concerto No.1       C major
# 36                                 Piano Concerto No.2  B flat major
# 60                                 Piano Concerto No.3       C minor
# ...

# %%
df.loc[df['title'].str.lower().str.contains('concerto'),['type']] = 'Concerto'

# %% [markdown]
# ## Vocal

# %%
df[df['genre']=='Vocal']
# Out:
#                 Op.             WoO          Hess          Biamonti  \
# 54           Op. 32             NaN           NaN      Biamonti 421
# 69           Op. 46             NaN           NaN      Biamonti 111
# 71     Op. 48 No. 1             NaN           NaN    Biamonti 367/1
# 72     Op. 48 No. 2             NaN           NaN    Biamonti 367/2
# 73     Op. 48 No. 3             NaN           NaN    Biamonti 367/3
# 74     Op. 48 No. 4             NaN           NaN    Biamonti 367/4
# 75     Op. 48 No. 5             NaN           NaN    Biamonti 367/5
# 76     Op. 48 No. 6             NaN           NaN    Biamonti 367/6
# 81     Op. 52 No. 1             NaN           NaN     Biamonti 34/1
# 82     Op. 52 No. 2             NaN           NaN     Biamonti 34/2
# 83     Op. 52 No. 3             NaN           NaN     Biamonti 34/3
# 84     Op. 52 No. 4             NaN           NaN     Biamonti 34/4
# 85     Op. 52 No. 5             NaN           NaN     Biamonti 34/5
# ...

# %%
df.loc[df['WoO']=='WoO 74',['type']]='VOID'

# %% [markdown]
# ### Song

# %%
df.loc[df['title'].str.lower().str.contains('song'),['type']]='Song'

# %%
df.loc[df['title'].str.lower().str.contains('lieder'),['type']]='Song'

# %%
df.loc[df['title'].str.lower().str.contains('gesänge'),['type']]='Song'

# %%
df.loc[df['title'].str.lower().str.contains('opferlied'),['type']]='Song'

# %%
df.loc[df['title'].str.lower().str.contains('lied'),['type']]='Song'

# %% [markdown]
# ###  Canon

# %%
df.loc[(df['title'].str.lower().str.contains('canon')) & (df['genre']=='Vocal'),['type']]='Canon'

# %%
df.loc[df['WoO']=='WoO 64',['type']]='VOID'

# %% [markdown]
# ### Cantata

# %%
df.loc[df['title'].str.lower().str.contains('cantata'),['type']]='Cantata'

# %%
df.loc[df['title'].str.lower().str.contains('cantate'),['type']]='Cantata'

# %%
df[df['Op.']=='Op. 112']
# Out:
#          Op.  WoO Hess      Biamonti  \
# 213  Op. 112  NaN  NaN  Biamonti 609
#
#                                                  title      key   scoring  \
# 213   Meeresstille und glückliche Fahrt(Calm Sea & ...  D major   ch orch
#
#           genre                   name    year  minor key_note  Unv.  one  \
# 213  Orchestral  Op. 112, Biamonti 609  1815.0    0.0        D   NaN    1
#
#     major-minor type
# 213       major  NaN

# %%
df.loc[df['Op.']=='Op. 112',['genre']]='Vocal'

# %%
df.loc[df['Op.']=='Op. 112',['type']]='Cantata'

# %% [markdown]
# ### Mass

# %%
df[df['title'].str.lower().str.contains('mass')]
# Out:
#         Op.  WoO Hess      Biamonti  title      key      scoring  genre  \
# 143  Op. 86  NaN  NaN  Biamonti 439   Mass  C major   4vvch orch  Vocal
#
#                      name    year  minor key_note  Unv.  one major-minor type
# 143  Op. 86, Biamonti 439  1807.0    0.0        C   NaN    1       major  NaN

# %%
df.loc[df['title'].str.lower().str.contains('mass'),['type']]='Mass'

# %%
df.loc[df['title'].str.lower().str.contains('missa'),['type']]='Mass'

# %% [markdown]
# ### mark remain vocal as song

# %%
df[(df['type'].isna()) & (df['genre']=='Vocal')]
# Out:
#               Op.            WoO          Hess        Biamonti  \
# 54         Op. 32            NaN           NaN    Biamonti 421
# 69         Op. 46            NaN           NaN    Biamonti 111
# 105        Op. 65            NaN           NaN    Biamonti 116
# 113        Op. 72            NaN      Hess 109    Biamonti 423
# 114        Op. 72            NaN      Hess 110    Biamonti 427
# 115        Op. 72            NaN           NaN    Biamonti 570
# 130        Op. 80            NaN           NaN    Biamonti 486
# 133  Op. 82 No. 1            NaN           NaN  Biamonti 513/1
# 134  Op. 82 No. 2            NaN           NaN  Biamonti 513/2
# 135  Op. 82 No. 3            NaN           NaN  Biamonti 513/3
# 136  Op. 82 No. 4            NaN           NaN  Biamonti 513/4
# 137  Op. 82 No. 5            NaN           NaN  Biamonti 513/5
# 142        Op. 85            NaN           NaN    Biamonti 363
# 145        Op. 88            NaN           NaN    Biamonti 370
# ...

# %%
df.loc[(df['type'].isna()) & (df['genre']=='Vocal'), ['type']]='Song'

# %% [markdown]
# ## Chamber

# %% [markdown]
# ### duo

# %%
df.loc[(df['title'].str.lower().str.contains('duo')),['type']] = 'Duo'

# %%
df.loc[(df['title'].str.lower().str.contains('duet')),['type']] = 'Duo'

# %%
df.loc[df['title'].str.lower().str.contains('national airs with variations'),['type']]='Duo'

# %% [markdown]
# ### trio

# %%
df.loc[(df['title'].str.lower().str.contains('trio')) & (df['title'].str.lower().str.contains('piano')),['type']] = 'Piano Trio'

# %%
df.loc[(df['title'].str.lower().str.contains('trio')) & (df['type']!='Piano Trio'),['type']] ='Trio (except Piano Trio)'

# %%
df.loc[df['Hess']==297,['type']]='Trio (except Piano Trio)'

# %% [markdown]
# ### Quartet

# %%
df.loc[(df['title'].str.lower().str.contains('quartet')) & (df['title'].str.lower().str.contains('string')),['type']] = 'String Quartet'

# %%
df.loc[(df['title'].str.lower().str.contains('quartet')) & (df['type']!='String Quartet') & (df['genre']=='Chamber'),['type']] = 'Quartet (except String Quartet)'

# %%
df.loc[df['Hess']=='Hess 238',['type']]='Quartet (except String Quartet)'

# %%
df.loc[df['Biamonti']==389,['type']]='Quartet (except String Quartet)'

# %% [markdown]
# ###  higher

# %%
df.loc[(df['title'].str.lower().str.contains('quintet')) ,['type']] = 'Quintet'

# %%
df.loc[(df['title'].str.lower().str.contains('sextet')),['type']]='Sextet, Septet or Octet'

# %%
df.loc[(df['title'].str.lower().str.contains('septet')),['type']]='Sextet, Septet or Octet'

# %%
df.loc[(df['title'].str.lower().str.contains('octet')),['type']]='Sextet, Septet or Octet'

# %% [markdown]
# save rest as other

# %%
df.loc[(df['genre']=='Chamber') & (df['type'].isna()),['type']]='Other'

# %%
df[(df['Op.']=='Op. 36') & (df['genre']=='Chamber')]
# Out:
#        Op.  WoO Hess      Biamonti           title      key    scoring  \
# 59  Op. 36  NaN  NaN  Biamonti 425   Symphony No.2  D major   vn vc pf
#
#       genre                  name    year  minor key_note  Unv.  one  \
# 59  Chamber  Op. 36, Biamonti 425  1805.0    0.0        D   NaN    1
#
#    major-minor      type
# 59       major  Symphony

# %%
df.loc[(df['Op.']=='Op. 36') & (df['genre']=='Chamber'),['type']]='Other'

# %%
df[(df['type']=='Other') & (df['genre']=='Chamber')]
# Out:
#           Op.      WoO          Hess          Biamonti  \
# 12      Op. 8      NaN           NaN      Biamonti 135
# 42     Op. 25      NaN           NaN      Biamonti 114
# 59     Op. 36      NaN           NaN      Biamonti 425
# 64     Op. 41      NaN   Hess Anh.12      Biamonti 371
# 65     Op. 42      NaN   Hess Anh.13      Biamonti 372
# 67     Op. 44      NaN           NaN      Biamonti 263
# 106    Op. 66      NaN           NaN      Biamonti 160
# 222  Op. 121a      NaN           NaN      Biamonti 654
# 237   Op. 133      NaN           NaN      Biamonti 830
# 241   Op. 137      NaN           NaN      Biamonti 678
# 256       NaN    WoO 9       Hess 26      Biamonti 101
# 265       NaN   WoO 15           NaN      Biamonti 324
# 268       NaN   WoO 17       Hess 20      Biamonti 710
# 282       NaN   WoO 25           NaN       Biamonti 40
# 286       NaN   WoO 28       Hess 18               NaN
# 289       NaN   WoO 30           NaN      Biamonti 548
# ...

# %%
df[(df['genre']=='Chamber')]['type'].value_counts()
# Out:
# Other                              34
# String Quartet                     29
# Duo                                21
# Piano Trio                         14
# Quintet                            12
# Sonata for Violin                  11
# Trio (except Piano Trio)           10
# Sonata for other instruments        8
# Sextet, Septet or Octet             5
# Quartet (except String Quartet)     5
# Name: type, dtype: int64

# %% [markdown]
# ## Keyboard

# %%
df[(df['genre']=='Keyboard') & (df['type'].isna())]
# Out:
#          Op.         WoO      Hess      Biamonti  \
# 55    Op. 33         NaN       NaN  Biamonti 334
# 56    Op. 34         NaN       NaN  Biamonti 327
# 57    Op. 35         NaN       NaN  Biamonti 328
# 62    Op. 39         NaN       NaN  Biamonti 375
# 68    Op. 45         NaN       NaN  Biamonti 377
# 80    Op. 51         NaN       NaN           NaN
# 126   Op. 76         NaN       NaN  Biamonti 494
# 127   Op. 77         NaN       NaN  Biamonti 492
# 146   Op. 89         NaN       NaN  Biamonti 588
# 220  Op. 119         NaN       NaN  Biamonti 745
# 221  Op. 120         NaN       NaN  Biamonti 774
# 229  Op. 126         NaN       NaN  Biamonti 788
# 232  Op. 129         NaN       NaN  Biamonti 162
# 238  Op. 134         NaN   Hess 86  Biamonti 841
# 253      NaN       WoO 7  Hess 101   Biamonti 92
# 255      NaN       WoO 8  Hess 100   Biamonti 93
# 258      NaN      WoO 10       NaN  Biamonti 102
# 260      NaN      WoO 11   Hess 27  Biamonti 163
# ...

# %%
df.loc[(df['genre']=='Keyboard')  & (df['title'].str.lower().str.contains('variation')),['type']] = 'Piano variations'

# %%
df.loc[(df['genre']=='Keyboard')  & (df['title'].str.lower().str.contains('bagatell')),['type']] = 'Bagatelle'

# %%
df.loc[(df['genre']=='Keyboard')  & (df['title'].str.lower().str.contains('cadenza')),['type']] = 'Cadenza for Piano'

# %%
df.loc[(df['genre']=='Keyboard')  & (df['title'].str.lower().str.contains('rondo')),['type']] = 'Rondo for Piano'

# %%
df.loc[(df['genre']=='Keyboard')  & (df['title'].str.lower().str.contains('fug')),['type']] = 'Fugue for Piano'

# %%
df.loc[(df['genre']=='Keyboard')  & (df['title'].str.lower().str.contains('sonat')) & (df['type'].isna()),['type']] = 'Sonata for Piano'

# %%
df.loc[(df['genre']=='Keyboard')  & (df['title'].str.lower().str.contains('minuet')),['type']] ='Minuet for Piano'

# %%
df.loc[(df['genre']=='Keyboard')  & (df['title'].str.lower().str.contains('waltz')),['type']] ='Waltz for Piano'

# %%
df.loc[(df['genre']=='Keyboard')  & (df['title'].str.lower().str.contains('march')) & (df['type'].isna()),['type']] ='March for Piano'

# %%
df[(df['genre']=='Keyboard')  & (df['title'].str.lower().str.contains('march'))]
# Out:
#         Op.     WoO     Hess      Biamonti  \
# 43   Op. 26     NaN      NaN  Biamonti 296
# 68   Op. 45     NaN      NaN  Biamonti 377
# 271     NaN  WoO 18  Hess 99  Biamonti 504
# 288     NaN  WoO 29  Hess 87           NaN
#
#                                                  title           key scoring  \
# 43                Piano Sonata No.12 ('Funeral March')  A flat major      pf
# 68                                         Marches (3)       unknown    pf4h
# 271   March ('Marsch für die bohmische Landwehr') (...       F major      pf
# 288   March for Wind Sextet in B-flat major('Grenad...  B flat major      pf
#
#         genre                  name    year  minor key_note  Unv.  one  \
# 43   Keyboard  Op. 26, Biamonti 296  1801.0    0.0   A flat   NaN    1
# 68   Keyboard  Op. 45, Biamonti 377  1803.0    NaN  unknown   NaN    1
# 271  Keyboard  WoO 18, Biamonti 504  1810.0    0.0        F   NaN    1
# 288  Keyboard                WoO 29  1798.0    0.0   B flat   NaN    1
#
# ...

# %%
df.loc[df['Hess']=='Hess 87',['type']]='March for Piano'

# %%
df.loc[(df['genre']=='Keyboard') & (df['type']=='Song'),['type']]='Other'

# %%
df.loc[df['Hess'] =='Hess 89',['genre']]='Keyboard'

# %%
df.loc[df['Hess'] =='Hess 89',['type']]='Other'

# %%
df[df['Hess']  =='Hess 89']
# Out:
#      Op.    WoO     Hess     Biamonti                         title      key  \
# 244  NaN  WoO 1  Hess 89  Biamonti 30   Musik zu einem Ritterballet  D major
#
#     scoring     genre                name    year  minor key_note  Unv.  one  \
# 244      pf  Keyboard  WoO 1, Biamonti 30  1791.0    0.0        D   NaN    1
#
#     major-minor   type
# 244       major  Other

# %%
df[df['Biamonti']=='Biamonti 177/418']
# Out:
#      Op.     WoO Hess          Biamonti  \
# 344  NaN  WoO 74  NaN  Biamonti 177/418
#
#                                                  title      key      scoring  \
# 344   Variations for Piano Four-Hands on 'Ich denke...  D major   pf4h (+ v)
#
#      genre                      name    year  minor key_note  Unv.  one  \
# 344  Vocal  WoO 74, Biamonti 177/418  1718.0    0.0        D   NaN    1
#
#     major-minor  type
# 344       major  VOID

# %%
df.loc[df['Biamonti']=='Biamonti 177/418',['genre']]='Keyboard'
df.loc[df['Biamonti']=='Biamonti 177/418',['type']]='Piano variations'

# %%
df[df['Hess']==96]
# Out:
#     Op.  WoO Hess Biamonti                                  title      key  \
# 42  NaN  NaN   96      NaN  Fragment of Symphony No. 7 for piano   unknown
#
#    scoring       genre     name    year  minor key_note  Unv.  one  \
# 42     NaN  Orchestral  Hess 96  1813.0    NaN  unknown   NaN    1
#
#     major-minor      type
# 42  unknown key  Symphony

# %%
df.loc[df['Hess']==96,['genre']]='Keyboard'
df.loc[df['Hess']==96,['type']]='Other'

# %% [markdown]
# rest as other

# %%
df.loc[(df['genre']=='Keyboard') & (df['type'].isna()),['type']] ='Other'

# %%
df[df['genre']=='Keyboard']['type'].value_counts()
# Out:
# Other                47
# Sonata for Piano     42
# Piano variations     24
# Bagatelle            10
# Cadenza for Piano    10
# Fugue for Piano       6
# Rondo for Piano       6
# Minuet for Piano      5
# Waltz for Piano       3
# March for Piano       3
# Name: type, dtype: int64

# %% [markdown]
# ## Orchestral

# %%
df[(df['genre']=='Orchestral') & df['type'].isna()]
# Out:
#          Op.     WoO      Hess        Biamonti  \
# 63    Op. 40     NaN       NaN    Biamonti 329
# 66    Op. 43     NaN       NaN    Biamonti 288
# 79    Op. 50     NaN       NaN    Biamonti 330
# 102   Op. 62     NaN       NaN    Biamonti 438
# 116  Op. 72a     NaN       NaN    Biamonti 423
# 117  Op. 72b     NaN       NaN    Biamonti 427
# 141   Op. 84     NaN       NaN    Biamonti 518
# 214  Op. 113     NaN  Hess 118    Biamonti 539
# 215  Op. 114     NaN  Hess 118    Biamonti 742
# 216  Op. 115     NaN       NaN    Biamonti 597
# 218  Op. 117     NaN       NaN    Biamonti 538
# 227  Op. 124     NaN  Hess 118    Biamonti 742
# 242  Op. 138     NaN       NaN    Biamonti 422
# 243      NaN   WoO 1       NaN     Biamonti 29
# 245      NaN   WoO 2       NaN             NaN
# 246      NaN  WoO 2a  Hess 117    Biamonti 553
# 247      NaN  WoO 2b  Hess 117    Biamonti 554
# 248      NaN   WoO 3       NaN    Biamonti 744
# 251      NaN   WoO 6       NaN    Biamonti 103
# ...

# %%
df.loc[(df['genre']=='Orchestral') & (df['title'].str.lower().str.contains('march')),['type']] ='March'

# %%
df.loc[(df['genre']=='Orchestral') & (df['title'].str.lower().str.contains('minuet')),['type']] = 'Minuet'

# %%
df.loc[(df['genre']=='Orchestral') & (df['title'].str.lower().str.contains('ecossai')),['type']] = 'Ecossaise'

# %% [markdown]
# #### overture

# %%
df.loc[(df['genre']=='Orchestral') & (df['title'].str.lower().str.contains('overt')),['type']] ='Overture'

# %%
df.loc[df['Op.'] == 'Op. 62',['type']] ='Overture'

# %%
df[df['type']=='Overture']
# Out:
#          Op.  WoO      Hess      Biamonti  \
# 102   Op. 62  NaN       NaN  Biamonti 438
# 116  Op. 72a  NaN       NaN  Biamonti 423
# 117  Op. 72b  NaN       NaN  Biamonti 427
# 216  Op. 115  NaN       NaN  Biamonti 597
# 227  Op. 124  NaN  Hess 118  Biamonti 742
# 242  Op. 138  NaN       NaN  Biamonti 422
#
#                                        title      key scoring       genre  \
# 102                                 Coriolan  C minor    orch  Orchestral
# 116                    Leonora Overture No.2  C major    orch  Orchestral
# 117                    Leonora Overture No.3  C major    orch  Orchestral
# 216   Overture  'Zur Namensfeier' (Name-Day)  C major    orch  Orchestral
# 227           Die Weihe des Hauses  overture  C major    orch  Orchestral
# 242                    Leonora Overture No.1  C major    orch  Orchestral
#
#                       name    year  minor key_note  Unv.  one major-minor  \
# ...

# %% [markdown]
# #### Incidental music

# %%
df.loc[df['Op.']=='Op. 84',['type']] = 'Incidental music'

# %%
df.loc[df['Op.']=='Op. 113',['type']] = 'Incidental music'

# %%
df.loc[df['Op.']=='Op. 114',['type']] = 'Incidental music'

# %%
df.loc[df['WoO']=='WoO 2',['type']] = 'Incidental music'

# %%
df.loc[df['Op.']=='Op. 117',['type']]= 'Incidental music'

# %%
df.loc[df['WoO']=='WoO 96',['type']]= 'Incidental music'

# %%
df.loc[df['WoO']=='WoO 3',['type']]= 'Incidental music'

# %%
df.loc[df['WoO']=='WoO 2b',['type']]= 'Incidental music'

# %% [markdown]
# #### ballet music

# %%
df.loc[(df['genre']=='Orchestral') & (df['title'].str.lower().str.contains('ball')),['type']] ='Music for Ballet'

# %%
df.loc[df['Op.']=='Op. 43',['type']]='Music for Ballet'

# %% [markdown]
# #### other work for soloist and orchestra

# %%
df.loc[df['Op.']=='Op. 40',['type']] = 'Other works for soloist and orchestra'

# %%
df.loc[df['Op.']=='Op. 50',['type']] = 'Other works for soloist and orchestra'

# %%
df.loc[df['WoO']=='WoO 6',['type']] = 'Other works for soloist and orchestra'

# %%
df.loc[df['Hess']==13,['type']] = 'Other works for soloist and orchestra'

# %%
df.loc[df['Hess']==11,['type']] = 'Other works for soloist and orchestra'

# %% [markdown]
# #### mark rest as others

# %%
df[(df['genre']=='Orchestral')&(df['type'].isna())]
# Out:
#      Op.     WoO      Hess      Biamonti                       title  \
# 254  NaN   WoO 8       NaN   Biamonti 89          German Dances (12)
# 259  NaN  WoO 11       NaN           NaN                 Ländler (7)
# 262  NaN  WoO 13       NaN           NaN          German Dances (12)
# 264  NaN  WoO 14       NaN  Biamonti 295           Contredanses (12)
# 278  NaN  WoO 21       NaN  Biamonti 520                   Polonaise
# 370  NaN  WoO 98  Hess 118  Biamonti 742   Wo sich die Pulse  chorus
#
#               key       scoring       genre                  name    year  \
# 254       unknown          orch  Orchestral    WoO 8, Biamonti 89  1795.0
# 259       unknown          orch  Orchestral                WoO 11  1799.0
# 262       unknown          orch  Orchestral                WoO 13  1797.0
# 264       unknown          orch  Orchestral  WoO 14, Biamonti 295  1718.0
# 278       D major    ww br perc  Orchestral  WoO 21, Biamonti 520  1810.0
# ...

# %%
df.loc[(df['genre']=='Orchestral')&(df['type'].isna()),['type']] ='Other'

# %%
df.loc[df['type']=='Ecossaise',['type']] = 'Other'

# %%
df[(df['genre']=='Orchestral')]['type'].value_counts()
# Out:
# Symphony                                 14
# Concerto                                 14
# Other                                    10
# March                                     9
# Incidental music                          8
# Overture                                  6
# Other works for soloist and orchestra     5
# Minuet                                    5
# Music for Ballet                          2
# Name: type, dtype: int64

# %% [markdown]
# ## last check

# %%
df['genre'].value_counts()
# Out:
# Vocal         247
# Keyboard      156
# Chamber       149
# Orchestral     73
# Name: genre, dtype: int64

# %%
tmp_drop=['name','minor','key_note','Unv.','one','major-minor','WoO','key']

# %%
df[df['genre']=='Orchestral']['type'].value_counts()
# Out:
# Symphony                                 14
# Concerto                                 14
# Other                                    10
# March                                     9
# Incidental music                          8
# Overture                                  6
# Other works for soloist and orchestra     5
# Minuet                                    5
# Music for Ballet                          2
# Name: type, dtype: int64

# %%
df[(df['genre']=='Orchestral') & (df['type']=='Concerto')].drop(columns=tmp_drop,axis=1)
# Out:
#          Op.     Hess      Biamonti  \
# 26    Op. 15      NaN  Biamonti 167
# 36    Op. 19      NaN  Biamonti 166
# 60    Op. 37      NaN  Biamonti 337
# 92    Op. 56      NaN  Biamonti 410
# 94    Op. 58      NaN  Biamonti 431
# 100   Op. 61      NaN  Biamonti 432
# 101  Op. 61a      NaN  Biamonti 441
# 118   Op. 73      NaN  Biamonti 499
# 249      NaN      NaN   Biamonti 10
# 250      NaN  Hess 10   Biamonti 33
# 2        NaN       14           NaN
# 24       NaN       65           NaN
# 3        NaN       15           NaN
# 0        NaN       12           NaN
#
#                                                  title         scoring  \
# 26                                 Piano Concerto No.1         pf orch
# 36                                 Piano Concerto No.2         pf orch
# 60                                 Piano Concerto No.3         pf orch
# 92                                     Triple Concerto   vn vc pf orch
# ...

# %%
df[(df['type']=='Music for Ballet')].drop(columns=tmp_drop,axis=1)
# Out:
#         Op. Hess      Biamonti  \
# 66   Op. 43  NaN  Biamonti 288
# 243     NaN  NaN   Biamonti 29
#
#                                                  title scoring       genre  \
# 66    Die Geschöpfe des Prometheus (The Creatures o...    orch  Orchestral
# 243                        Musik zu einem Ritterballet    orch  Orchestral
#
#        year              type
# 66   1801.0  Music for Ballet
# 243  1791.0  Music for Ballet

# %% [markdown]
# # SAVE

# %%
df.drop(columns=['one'], inplace=True)

# %%
pd.options.display.float_format = '{:,.0f}'.format

# %%
df.iloc[100:200]
# Out:
#                 Op.  WoO         Hess         Biamonti  \
# 102          Op. 62  NaN          NaN     Biamonti 438
# 103          Op. 63  NaN  Hess Anh.14   Biamonti II/65
# 104          Op. 64  NaN  Hess Anh.15   Biamonti II/60
# 105          Op. 65  NaN          NaN     Biamonti 116
# 106          Op. 66  NaN          NaN     Biamonti 160
# 107          Op. 67  NaN          NaN     Biamonti 443
# 108          Op. 68  NaN          NaN     Biamonti 453
# 109          Op. 69  NaN          NaN     Biamonti 444
# 110    Op. 70 No. 1  NaN          NaN   Biamonti 455/1
# 111    Op. 70 No. 2  NaN          NaN   Biamonti 455/2
# 112          Op. 71  NaN          NaN     Biamonti 118
# 113          Op. 72  NaN     Hess 109     Biamonti 423
# 114          Op. 72  NaN     Hess 110     Biamonti 427
# 115          Op. 72  NaN          NaN     Biamonti 570
# 116         Op. 72a  NaN          NaN     Biamonti 423
# 117         Op. 72b  NaN          NaN     Biamonti 427
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 682 entries, 0 to 25
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Op.          240 non-null    object
#  1   WoO          292 non-null    object
#  2   Hess         226 non-null    object
#  3   Biamonti     546 non-null    object
#  4   title        682 non-null    object
#  5   key          682 non-null    object
#  6   scoring      515 non-null    object
#  7   genre        625 non-null    object
#  8   name         682 non-null    object
#  9   year         640 non-null    float64
#  10  minor        480 non-null    float64
#  11  key_note     682 non-null    object
#  12  Unv.         19 non-null     float64
#  13  major-minor  682 non-null    object
#  14  type         625 non-null    object
# dtypes: float64(3), object(12)
# memory usage: 85.2+ KB

# %%
df.to_csv('df_fv.csv',index=False)

# %% [markdown]
# # Changes in df_fv.csv

# %%
df_ch = pd.read_csv('df_fv.csv')

# %%
df_ch
# Out:
#                 Op.             WoO          Hess          Biamonti  \
# 0       Op. 1 No. 1             NaN           NaN     Biamonti 62/1
# 1       Op. 1 No. 2             NaN           NaN     Biamonti 62/2
# 2       Op. 1 No. 3             NaN           NaN     Biamonti 62/3
# 3       Op. 2 No. 1             NaN           NaN     Biamonti 87/1
# 4       Op. 2 No. 2             NaN           NaN     Biamonti 87/2
# 5       Op. 2 No. 3             NaN           NaN     Biamonti 87/3
# 6             Op. 3             NaN           NaN      Biamonti 105
# 7             Op. 4             NaN           NaN      Biamonti 115
# 8       Op. 5 No. 1             NaN           NaN    Biamonti 106/1
# 9       Op. 5 No. 2             NaN           NaN    Biamonti 106/2
# 10            Op. 6             NaN           NaN      Biamonti 134
# 11            Op. 7             NaN           NaN      Biamonti 136
# 12            Op. 8             NaN           NaN      Biamonti 135
# ...

# %%
df_ch[df_ch['Op.']=='Op. 68']
# Out:
#         Op.  WoO Hess      Biamonti           title      key scoring  \
# 106  Op. 68  NaN  NaN  Biamonti 453   Symphony No.6  F major    orch
#
#           genre                  name  year  minor key_note  Unv. major-minor  \
# 106  Orchestral  Op. 68, Biamonti 453 1,807      0        F   nan       major
#
#          type
# 106  Symphony

# %%
df_ch[df_ch['Op.']=='Op. 67']
# Out:
#         Op.  WoO Hess      Biamonti           title      key scoring  \
# 105  Op. 67  NaN  NaN  Biamonti 443   Symphony No.5  C minor    orch
#
#           genre                  name  year  minor key_note  Unv. major-minor  \
# 105  Orchestral  Op. 67, Biamonti 443 1,804      1        C   nan       minor
#
#          type
# 105  Symphony

# %%
df_ch[df_ch['Op.']=='Op. 60']
# Out:
#        Op.  WoO Hess      Biamonti           title           key scoring  \
# 97  Op. 60  NaN  NaN  Biamonti 429   Symphony No.4  B flat major    orch
#
#          genre                  name  year  minor key_note  Unv. major-minor  \
# 97  Orchestral  Op. 60, Biamonti 429 1,806      0   B flat   nan       major
#
#         type
# 97  Symphony

# %%
df_ch.loc[df_ch['Op.']=='Op. 67',['year']]=1808

# %%
df_ch.loc[df_ch['Op.']=='Op. 68',['year']]=1808

# %%
df_ch.to_csv('df_fv.csv',index=False)
